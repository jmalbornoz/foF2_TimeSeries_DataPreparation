# %% [markdown]
# # 4.- Cleansed Chilton f0F2 time series EDA - Low Solar Activity
# ## July 2022
# ### Dr Jose M Albornoz
#
# In this notebook we filter a dataset containing hourly values of f0F2 plus hourly values of the solar and geomagnetic parameters that influence electron content in the ionosphere; this filtering is done for a period of low solar activity. Periods of low and enhanced geomagnetic activity are identified for the reduced solar activity dataset.

# %% [markdown]
# # Import necessary modules

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import cm
style.use('fivethirtyeight')
# %matplotlib inline

import random
import time

RANDOM_STATE = 801
pd.options.mode.chained_assignment = None

# maximum number of rdataframe ows and columns displayed
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# Solar & geomagnetic data was downloaded from NASA’s Space Physics Data Facility (SPDF) OMNI (Operating Missions as a Node on the Internet) https://omniweb.gsfc.nasa.gov/form/dx1.html. The following parameters are included in this dataset:

# %% [markdown]
# - **Timestamp**: hourly timestamp in format YYYY-mm-DD HH:MM:SS
# - **f0f2**: F2 critical frquency, MHz
# - **Scalar B, nt**: Average Scalar Interplanetary Magnetic Field (IMF). A combined measure of the magnetic field strength in the north-south, east-west, and towards-Sun vs. away-from-Sun directions (https://www.spaceweatherlive.com/en/help/the-interplanetary-magnetic-field-imf.html).
# - **Vector B Magnitude, nt**: Magnitude of IMF vector, $|<B>|$
# - **Bx, By, Bz**: IMF components in Geocentric Solar Ecliptic (GSE) and Geocentric Solar Magnetospheric (GSM) coordiantes (https://www.spenvis.oma.be/help/background/coortran/coortran.html#GSE)
# - **RMS_magnitude, nt**: RMS standard deviation in average IMF magnitude
# - **RMS_field_vector, nT**: RMS standard deviation in IMF vector
# - **RMS_BX_GSE, RMS_BY_GSE, RMS_BZ_GSE**: Standard deviation in GSE X, Y and Z IMF components
# - **SW Plasma Temperature, K**: Solar wind plasma temperature
# - **SW Proton Density, N/cm^3**: Solar wind proton density
# - **SW Plasma Speed, km/s**: Solar wind plasma speed
# - **Alpha/Proton ratio**: He$^{++}$/H$^+$ ratio
# - **sigma-T, K**: Solar wind plasma temperature	standard deviation
# - **sigma-n, N/cm^3**: Solar wind proton density standard deviation												- - - - **sigma-V, km/s**: Solar wind plasma speed standard deviation
# - **sigma-ratio**: He$^{++}$/H$^+$ ratio standard deviation
# - **Kp index*10**: Planetary k-index (multiplied by 10)
# - **R (Sunspot No.)**: Sunspot number
# - **Dst-index, nT**: Disturbance storm time index
# - **ap_index, nT**: Daily average level for geomagnetic activity
# - **f10.7_index**: Solar radio flux at a wavelength of 10.7 cm at the earth's orbit
# - **AE-index, nT, AL-index, nT, AU-index, nT**: Auroral zone magnetic disturbance levels indices
# - **pc-index**: Polar cap magnetic index
# - **Lyman_alpha**: Hydrogen Lyman α emission
# - **Proton flux (>1 Mev), Proton flux (>2 Mev), Proton flux (>4 Mev), Proton flux (>10 Mev), Proton flux (>30 Mev), Proton flux (>60 Mev)**: Solar proton flux
# - **Flux FLAG**: Magnetospheric Flux Flag

# %% [markdown]
# # 1.- Load data

# %%
df_0 = pd.read_csv("Data/merged_f0F2_solar_geomagnetic_v2.csv")

# %%
df_0.shape
# Out:
# (100032, 39)

# %%
df_0['Timestamp'] = pd.to_datetime(df_0['Timestamp'])

# %%
df_0['Timestamp'].min()
# Out:
# Timestamp('1995-02-01 00:00:00')

# %%
df_0['Timestamp'].max()
# Out:
# Timestamp('2006-06-30 23:00:00')

# %%
df_0.set_index('Timestamp', inplace=True)

# %% [markdown]
# # 2.- Solar Activity Plots

# %% [markdown]
# We will now plot some relevant parameters to identify a period of low solar activity.

# %% [markdown]
# ## 2.1.- R (Sunspot Number)

# %%
plt.figure(figsize=(12,10))
plt.plot(df_0.index, df_0['R (Sunspot No.)'], color='blue')

plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('Number', fontsize=14)
plt.title('R', fontsize=20)
# Out:
# Text(0.5, 1.0, 'R')

# %% [markdown]
# ## 2.2.- f10.7 Index

# %%
plt.figure(figsize=(12,10))
plt.plot(df_0.index, df_0['f10.7_index'], color='blue')

plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('SFU', fontsize=14)
plt.title('f10.7 Index', fontsize=20)
# Out:
# Text(0.5, 1.0, 'f10.7 Index')

# %% [markdown]
# ## 2.3.- Lyman Alpha

# %%
plt.figure(figsize=(12,10))
plt.plot(df_0.index, df_0['Lyman_alpha'], color='blue')

plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('', fontsize=14)
plt.title('Lyman Alpha', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Lyman Alpha')

# %% [markdown]
# # 3.- Low Solar Activity Period Identification

# %% [markdown]
# As observed in the above plots, there is a period with low solar activity during 1996.

# %%
low_solar_activity1 = (df_0.index >= '1996-01-01 00:00:00') & (df_0.index < '1997-01-01 00:00:00')

# %%
df_1 = df_0[low_solar_activity1]

# %%
f = plt.figure(figsize=(12,8))
ax0 = f.add_subplot(311)
ax1 = f.add_subplot(312)
ax2 = f.add_subplot(313)

ax0.plot(df_1.index, df_1['R (Sunspot No.)'], color='blue')
ax0.title.set_text('R')

ax1.plot(df_1.index, df_1['f10.7_index'], color='blue')
ax1.title.set_text('f10.7_index')

ax2.plot(df_1.index, df_1['Lyman_alpha'], color='blue')
ax2.title.set_text('Lyman Alpha')

f.tight_layout()

# %% [markdown]
# Interestingly, we observe that for September-October 1996 the solar spot count was 0.

# %% [markdown]
# # 4.- Geomagnetic Activity Plots

# %% [markdown]
# ## 4.1.- Kp Index*10

# %%
plt.figure(figsize=(12,10))
plt.plot(df_1.index, df_1['Kp index'], color='blue')

plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('Adimensional', fontsize=14)
plt.title('Kp', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Kp')

# %% [markdown]
# ## 4.2.- $a_p$ Index

# %%
plt.figure(figsize=(12,10))
plt.plot(df_1.index, df_1['ap_index, nT'], color='blue')

plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('nT', fontsize=14)
plt.title('$a_p$ Index', fontsize=20)
# Out:
# Text(0.5, 1.0, '$a_p$ Index')

# %% [markdown]
# ## 4.3.- DST Index

# %%
plt.figure(figsize=(12,10))
plt.plot(df_1.index, df_1['Dst-index, nT'], color='blue')

plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('nT', fontsize=14)
plt.title('DST Index', fontsize=20)
# Out:
# Text(0.5, 1.0, 'DST Index')

# %% [markdown]
# # 5.- Low geomagnetic activity period identification

# %%
plt.figure(figsize=(15,12))
plt.plot(df_1.index, df_1['Kp index'], color='blue', label='Kp index',  linewidth=1)
plt.plot(df_1.index, df_1['ap_index, nT'], color='red', label='ap_index',  linewidth=1)
plt.plot(df_1.index, df_1['Dst-index, nT'], color='green', label='Dst-index',  linewidth=1)
plt.legend(loc='upper left')
plt.title("Geomagnetic indexes", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Geomagnetic indexes')

# %% [markdown]
# From the above plots a period of low geomagnetic activity is observed for May-August 1996

# %%
low_geomagnetic_activity = (df_1.index >= '1996-04-15 00:00:00') & (df_1.index < '1996-08-30 00:00:00')

# %%
df_2 = df_1[low_geomagnetic_activity]

# %%
plt.figure(figsize=(15,12))
plt.plot(df_2.index, df_2['Kp index'], color='blue', label='Kp index',  linewidth=1)
plt.plot(df_2.index, df_2['ap_index, nT'], color='red', label='ap_index',  linewidth=1)
plt.plot(df_2.index, df_2['Dst-index, nT'], color='green', label='Dst-index',  linewidth=1)
plt.legend(loc='upper left')
plt.title("Low geomagnetic activity period", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Low geomagnetic activity period')

# %% [markdown]
# We will now compare geomagnetic indexes stats for the whole of 1996 (df_1) and for the period of decreased geomagnetic activity (df_2):

# %%
df_1['Kp index'].describe()
# Out:
# count    8784.000000
# mean       18.908811
# std        11.311675
# min         0.000000
# 25%        10.000000
# 50%        17.000000
# 75%        27.000000
# max        73.000000
# Name: Kp index, dtype: float64

# %%
df_2['Kp index'].describe()
# Out:
# count    3288.000000
# mean       16.605839
# std         9.437530
# min         0.000000
# 25%        10.000000
# 50%        13.000000
# 75%        23.000000
# max        57.000000
# Name: Kp index, dtype: float64

# %%
df_1['ap_index, nT'].describe()
# Out:
# count    8784.000000
# mean        9.327527
# std         9.814381
# min         0.000000
# 25%         4.000000
# 50%         6.000000
# 75%        12.000000
# max       154.000000
# Name: ap_index, nT, dtype: float64

# %%
df_2['ap_index, nT'].describe()
# Out:
# count    3288.000000
# mean        7.434307
# std         6.737140
# min         0.000000
# 25%         4.000000
# 50%         5.000000
# 75%         9.000000
# max        67.000000
# Name: ap_index, nT, dtype: float64

# %%
df_1['Dst-index, nT'].describe()
# Out:
# count    8784.000000
# mean      -10.883652
# std        13.052732
# min      -105.000000
# 25%       -19.000000
# 50%        -9.000000
# 75%        -2.000000
# max        40.000000
# Name: Dst-index, nT, dtype: float64

# %%
df_2['Dst-index, nT'].describe()
# Out:
# count    3288.000000
# mean       -4.371959
# std        11.089344
# min       -56.000000
# 25%       -10.000000
# 50%        -3.000000
# 75%         3.000000
# max        40.000000
# Name: Dst-index, nT, dtype: float64

# %% [markdown]
# We see that the mean and median of the indexes for the period of reduced geomagnetic activity are lower.

# %% [markdown]
# Let's examine the series for f0F2 during this period. We begin by examining the percentage of missing values:

# %%
df_2['f0f2'].isna().sum()*100/len(df_2)
# Out:
# 10.644768856447689

# %%
plt.figure(figsize=(15,10))
plt.plot(df_2.index, df_2['f0f2'], color='blue')

plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('FoF2 (MHz)', fontsize=14)
plt.title('Chilton f0F2 time series, low solar activity, low geomagnetic activity', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Chilton f0F2 time series, low solar activity, low geomagnetic activity')

# %% [markdown]
# In order to avoid the missing values around July 15th, we will change the range of dates covered by the period of low geomagnetic activity.

# %%
low_geomagnetic_activity = (df_1.index >= '1996-05-01 00:00:00') & (df_1.index < '1996-07-13 00:00:00')

# %%
df_2 = df_1[low_geomagnetic_activity]

# %%
df_2['f0f2'].tail()
# Out:
# Timestamp
# 1996-07-12 19:00:00    6.1
# 1996-07-12 20:00:00    5.9
# 1996-07-12 21:00:00    5.0
# 1996-07-12 22:00:00    4.3
# 1996-07-12 23:00:00    4.0
# Name: f0f2, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.plot(df_2.index, df_2['f0f2'], color='blue')

plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('FoF2 (MHz)', fontsize=14)
plt.title('Chilton f0F2 time series, low solar activity, low geomagnetic activity', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Chilton f0F2 time series, low solar activity, low geomagnetic activity')

# %%
len(df_2)
# Out:
# 1752

# %%
df_2['f0f2'].isna().sum()*100/len(df_2)
# Out:
# 5.308219178082192

# %%
df_2.index.min()
# Out:
# Timestamp('1996-05-01 00:00:00')

# %%
df_2.index.max()
# Out:
# Timestamp('1996-07-12 23:00:00')

# %% [markdown]
# Let's compare again mean and median values of geomanetic indexes

# %%
df_1['Kp index'].describe()
# Out:
# count    8784.000000
# mean       18.908811
# std        11.311675
# min         0.000000
# 25%        10.000000
# 50%        17.000000
# 75%        27.000000
# max        73.000000
# Name: Kp index, dtype: float64

# %%
df_2['Kp index'].describe()
# Out:
# count    1752.000000
# mean       14.652397
# std         8.159227
# min         0.000000
# 25%        10.000000
# 50%        13.000000
# 75%        20.000000
# max        43.000000
# Name: Kp index, dtype: float64

# %%
df_1['ap_index, nT'].describe()
# Out:
# count    8784.000000
# mean        9.327527
# std         9.814381
# min         0.000000
# 25%         4.000000
# 50%         6.000000
# 75%        12.000000
# max       154.000000
# Name: ap_index, nT, dtype: float64

# %%
df_2['ap_index, nT'].describe()
# Out:
# count    1752.000000
# mean        6.116438
# std         4.200449
# min         0.000000
# 25%         4.000000
# 50%         5.000000
# 75%         7.000000
# max        32.000000
# Name: ap_index, nT, dtype: float64

# %%
df_1['Dst-index, nT'].describe()
# Out:
# count    8784.000000
# mean      -10.883652
# std        13.052732
# min      -105.000000
# 25%       -19.000000
# 50%        -9.000000
# 75%        -2.000000
# max        40.000000
# Name: Dst-index, nT, dtype: float64

# %%
df_2['Dst-index, nT'].describe()
# Out:
# count    1752.000000
# mean       -1.126142
# std         9.065380
# min       -33.000000
# 25%        -7.000000
# 50%        -1.000000
# 75%         5.000000
# max        40.000000
# Name: Dst-index, nT, dtype: float64

# %%
df_2.reset_index(inplace=True)

# %%
df_2.to_csv("Data/LowSolar_LowGeomagnetic.csv", index=False)

# %% [markdown]
# # 6.- Period of high geomagnetic activity identification

# %% [markdown]
# A period of enhanced geomagnetic activity is identified between January and May 1996.

# %%
high_geomagnetic_activity = (df_1.index >= '1996-01-01 00:00:00') & (df_1.index < '1996-05-31 00:00:00')

# %%
df_3 = df_1[high_geomagnetic_activity]

# %%
plt.figure(figsize=(15,12))
plt.plot(df_3.index, df_3['Kp index'], color='blue', label='Kp index',  linewidth=1)
plt.plot(df_3.index, df_3['ap_index, nT'], color='red', label='ap_index',  linewidth=1)
plt.plot(df_3.index, df_3['Dst-index, nT'], color='green', label='Dst-index',  linewidth=1)
plt.legend(loc='upper left')
plt.title("High geomagnetic activity period", fontsize=16)
# Out:
# Text(0.5, 1.0, 'High geomagnetic activity period')

# %%
closer_look = (df_3.index >= '1996-04-09 00:00:00') & (df_3.index < '1996-04-21 00:00:00')
closer_look_df = df_3[closer_look]

plt.figure(figsize=(15,12))
plt.plot(closer_look_df.index, closer_look_df['Kp index'], color='blue', label='Kp index',  linewidth=1)
plt.plot(closer_look_df.index, closer_look_df['ap_index, nT'], color='red', label='ap_index',  linewidth=1)
plt.plot(closer_look_df.index, closer_look_df['Dst-index, nT'], color='green', label='Dst-index',  linewidth=1)
plt.legend(loc='upper left')
plt.grid(which='major', alpha=1)

# %% [markdown]
# We observe a large spike in geomagnetic activity around April 15th.

# %% [markdown]
# We will now compare geomagnetic indexes stats for the period of reduced geomagnetic activity (df_2) and for the period of increased geomagnetic activity (df_3):

# %%
df_2['Kp index'].describe()
# Out:
# count    1752.000000
# mean       14.652397
# std         8.159227
# min         0.000000
# 25%        10.000000
# 50%        13.000000
# 75%        20.000000
# max        43.000000
# Name: Kp index, dtype: float64

# %%
df_3['Kp index'].describe()
# Out:
# count    3624.000000
# mean       19.820364
# std        11.022122
# min         0.000000
# 25%        10.000000
# 50%        20.000000
# 75%        27.000000
# max        70.000000
# Name: Kp index, dtype: float64

# %%
df_2['ap_index, nT'].describe()
# Out:
# count    1752.000000
# mean        6.116438
# std         4.200449
# min         0.000000
# 25%         4.000000
# 50%         5.000000
# 75%         7.000000
# max        32.000000
# Name: ap_index, nT, dtype: float64

# %%
df_3['ap_index, nT'].describe()
# Out:
# count    3624.000000
# mean        9.700331
# std         9.455863
# min         0.000000
# 25%         4.000000
# 50%         7.000000
# 75%        12.000000
# max       132.000000
# Name: ap_index, nT, dtype: float64

# %%
df_2['Dst-index, nT'].describe()
# Out:
# count    1752.000000
# mean       -1.126142
# std         9.065380
# min       -33.000000
# 25%        -7.000000
# 50%        -1.000000
# 75%         5.000000
# max        40.000000
# Name: Dst-index, nT, dtype: float64

# %%
df_3['Dst-index, nT'].describe()
# Out:
# count    3624.000000
# mean      -11.967439
# std        12.847265
# min       -90.000000
# 25%       -20.000000
# 50%       -10.000000
# 75%        -3.000000
# max        40.000000
# Name: Dst-index, nT, dtype: float64

# %% [markdown]
# We observe that the stats present increased mean and median values in the period of enhanced geomagnetic activity.

# %%
len(df_3)
# Out:
# 3624

# %%
df_3['f0f2'].isna().sum()*100/len(df_3)
# Out:
# 12.334437086092715

# %%
plt.figure(figsize=(15,10))
plt.plot(df_3.index, df_3['f0f2'], color='blue')

plt.xlabel('Timestamp', fontsize=14)
plt.ylabel('FoF2 (MHz)', fontsize=14)
plt.title('Chilton f0F2 time series', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Chilton f0F2 time series')

# %%
df_3.index.min()
# Out:
# Timestamp('1996-01-01 00:00:00')

# %%
df_3.index.max()
# Out:
# Timestamp('1996-05-30 23:00:00')

# %%
df_3.reset_index(inplace=True)

# %%
df_3.to_csv("Data/LowSolar_HighGeomagnetic.csv", index=False)
